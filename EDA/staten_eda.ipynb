# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy.spatial import cKDTree

# %%
csv = '../AnalysisReadyDataFrames/stat_df.csv'
df = pd.DataFrame(pd.read_csv(csv))

# %%
df.head()
# Out:
#          Borough            Area               Address  Num_Beds  Num_Baths  \
# 0  staten-island  New Dorp Beach     48C Winham Avenue       0.5        1.0
# 1  staten-island     Eltingville  3676 Richmond Avenue       3.0        1.0
# 2  staten-island    Saint George    36 Hamilton Avenue       2.0        1.0
# 3  staten-island    Saint George    36 Hamilton Avenue       1.0        1.0
# 4  staten-island    Saint George    60 Hamilton Avenue       2.0        1.0
#
#      Sq-Ft    Rent       Long        Lat  ZipCode  Precinct  \
# 0   513.32  1199.0 -74.103650  40.565749  10306.0     120.0
# 1  1500.00  2400.0 -74.167172  40.548162  10312.0     123.0
# 2   900.00  2150.0 -74.078906  40.644986  10301.0     120.0
# 3   750.00  1600.0 -74.078906  40.644986  10301.0     120.0
# 4   833.22  1950.0 -74.079733  40.644802  10301.0     120.0
#
#    CrimeTotalPastYear
# 0               799.0
# 1               338.0
# 2               799.0
# 3               799.0
# 4               799.0

# %%
# write lines aggregate to file for later use
with open('sublines_agg.json', 'r') as fp:
    lines_data = json.load(fp)

# %%
train_lines_ckd = {}

# %%
def create_lines_ckd(ckd_map:dict, lines_data:dict):
    for line in lines_data.keys():
        if line not in ckd_map:
            ckd_map[line] = None
        
        ckd_map[line] = cKDTree(lines_data[line])

# %%
create_lines_ckd(train_lines_ckd, lines_data)

# %%
train_lines_ckd.keys()
# Out:
# dict_keys(['G', 'Q', 'M', 'S', 'A', 'B-D', 'B-D-F-M', 'R', 'N-Q-R', 'N-Q', 'N-R', 'F', 'F-M', 'E', '7', 'J-Z', 'L', 'A-C', 'D', '1-2-3', 'B', '4-5-6', 'N', '1', 'N-W', '2-3', '2', '4-5', '5', '4', '3', 'A-C-E', 'N-Q-R-W', 'N-R-W', '6', 'R-W'])

# %%
def grid_search_line(lon, lat):
    nearests = []
    for line in train_lines_ckd:
        dist, _ = train_lines_ckd[line].query([lon, lat], k=1)
        nearests.append([dist, line])
    
    nearests.sort(key= lambda x: x[0])

    return nearests[0][1]

# %%
df['Train_Line'] = None

# %%
for idx, row in df.iterrows():
    lon, lat = row['Long'], row['Lat'],
    line_nearest = grid_search_line(lon, lat)
    df.at[idx, 'Train_Line'] = line_nearest

# %%
df
# Out:
#           Borough                       Area                   Address  \
# 0   staten-island             New Dorp Beach         48C Winham Avenue
# 1   staten-island                Eltingville      3676 Richmond Avenue
# 2   staten-island               Saint George        36 Hamilton Avenue
# 3   staten-island               Saint George        36 Hamilton Avenue
# 4   staten-island               Saint George        60 Hamilton Avenue
# 5   staten-island               Saint George        60 Hamilton Avenue
# 6   staten-island              Midland Beach        51 Boundary Avenue
# 7   staten-island                Tottenville           203 Main Street
# 8   staten-island               Richmondtown         19E Franklin Lane
# 9   staten-island               Saint George         133 Winter Avenue
# 10  staten-island                   Annadale       228 Shotwell Avenue
# 12     120.0               799.0          R
# 13     120.0               799.0          R
# 14     120.0               799.0          R
# 15     120.0               799.0          R
# 16     123.0               338.0          R
# 17     123.0               338.0          R
# 18     120.0               799.0          R
# 19     120.0               799.0          R
# 20     120.0               799.0          R
# 21     120.0               799.0          R
# 22     121.0               738.0          R
# 23     120.0               799.0          R
# 24     123.0               338.0          R
# 25     123.0               338.0          R
# 26     120.0               799.0          R
# 27     123.0               338.0          R
# 28     120.0               799.0          R
# 29     123.0               338.0          R
# 30     120.0               799.0          R
# 31     123.0               338.0          R
# 32     123.0               338.0          R
# 33     120.0               799.0          R
# 34     120.0               799.0          R
# 35     120.0               799.0          R
# 36     121.0               738.0          R
# 37     123.0               338.0          R
# 38     120.0               799.0          R
# 39     120.0               799.0          R
# 40     123.0               338.0          R
# 41     120.0               799.0          R
# 42     120.0               799.0          R
# 43     120.0               799.0          R
# 44     123.0               338.0          R
# 45     123.0               338.0          R
# 46     123.0               338.0          R
# 47     120.0               799.0          R

# %%
df.to_csv(csv, index=False)

# %%
df.columns
# Out:
# Index(['Borough', 'Area', 'Address', 'Num_Beds', 'Num_Baths', 'Sq-Ft', 'Rent',
#        'Long', 'Lat', 'ZipCode', 'Precinct', 'CrimeTotalPastYear',
#        'Train_Line'],
#       dtype='object')

# %%
# Bed, Bath, Sq-Ft, Rent, Correlation

df1 = df[['Num_Beds', 'Num_Baths', 'Sq-Ft', 'Rent']]

# %%
corr_mat1 = df1.corr(method='pearson')
mask = np.triu(np.ones_like(corr_mat1, dtype=bool))

f, ax = plt.subplots(figsize=(11, 11))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_mat1, mask=mask, cmap=cmap, robust=True, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Rent', size='Sq-Ft', sizes=(50, 650))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Train_Line', size='Rent', sizes=(50, 700), palette=sns.color_palette('deep', df['Train_Line'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='CrimeTotalPastYear', size='Rent', sizes=(50, 650))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Area', size='Rent', sizes=(50, 700), palette=sns.color_palette('deep', df['Area'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# correlation between crime and rent

df3 = df[['Sq-Ft', 'Num_Beds', 'Num_Baths', 'CrimeTotalPastYear', 'Rent']]

# %%
corr_mat3 = df3.corr(method='pearson')
mask = np.triu(np.ones_like(corr_mat3, dtype=bool))

f, ax = plt.subplots(figsize=(11, 11))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_mat3, mask=mask, cmap=cmap, robust=True, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Precinct', size='CrimeTotalPastYear', sizes=(50, 700), palette=sns.color_palette('deep', df['Precinct'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
