# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy.spatial import cKDTree

# %%
csv = '../AnalysisReadyDataFrames/manhatt_df.csv'
df = pd.DataFrame(pd.read_csv(csv))

# %%
df.head()
# Out:
#      Borough                           Area                Address  Num_Beds  \
# 0  manhattan                        Chelsea      130 W 15th Street       2.0
# 1  manhattan                    Murray Hill   401 East 34th Street       2.0
# 2  manhattan             Washington Heights  432 West 163rd Street       2.0
# 3  manhattan                   South Harlem  207 West 121st Street       0.5
# 4  manhattan  upper east side-carnegie hill      420 E 54th Street       1.0
#
#    Num_Baths    Sq-Ft    Rent       Long        Lat ZipCode  Precinct  \
# 0        2.0  1377.37  9150.0 -73.997478  40.738415   10011      13.0
# 1        2.0  1085.00  6276.0 -73.972708  40.743649   10016      13.0
# 2        1.0   855.99  2646.0 -73.938373  40.836002   10032      33.0
# 3        1.0   537.89  1950.0 -73.950435  40.806607   10027      28.0
# 4        2.0   851.00  5869.0 -73.963335  40.755807   10022      18.0
#
#    CrimeTotalPastYear
# 0              1549.0
# 1              1549.0
# 2              1126.0
# 3              1017.0
# 4              1926.0

# %%
# write lines aggregate to file for later use
with open('sublines_agg.json', 'r') as fp:
    lines_data = json.load(fp)

# %%
train_lines_ckd = {}

# %%
def create_lines_ckd(ckd_map:dict, lines_data:dict):
    for line in lines_data.keys():
        if line not in ckd_map:
            ckd_map[line] = None
        
        ckd_map[line] = cKDTree(lines_data[line])

# %%
create_lines_ckd(train_lines_ckd, lines_data)

# %%
train_lines_ckd.keys()
# Out:
# dict_keys(['G', 'Q', 'M', 'S', 'A', 'B-D', 'B-D-F-M', 'R', 'N-Q-R', 'N-Q', 'N-R', 'F', 'F-M', 'E', '7', 'J-Z', 'L', 'A-C', 'D', '1-2-3', 'B', '4-5-6', 'N', '1', 'N-W', '2-3', '2', '4-5', '5', '4', '3', 'A-C-E', 'N-Q-R-W', 'N-R-W', '6', 'R-W'])

# %%
def grid_search_line(lon, lat):
    nearests = []
    for line in train_lines_ckd:
        dist, _ = train_lines_ckd[line].query([lon, lat], k=1)
        nearests.append([dist, line])
    
    nearests.sort(key= lambda x: x[0])

    return nearests[0][1]

# %%
df['Train_Line'] = None

# %%
for idx, row in df.iterrows():
    lon, lat = row['Long'], row['Lat'],
    line_nearest = grid_search_line(lon, lat)
    df.at[idx, 'Train_Line'] = line_nearest

# %%
df
# Out:
#         Borough                           Area                 Address  \
# 0     manhattan                        Chelsea       130 W 15th Street
# 1     manhattan                    Murray Hill    401 East 34th Street
# 2     manhattan             Washington Heights   432 West 163rd Street
# 3     manhattan                   South Harlem   207 West 121st Street
# 4     manhattan  upper east side-carnegie hill       420 E 54th Street
# ...         ...                            ...                     ...
# 8638  manhattan                 Central Harlem   272 West 139th Street
# 8639  manhattan                          NoMad     50 East 28th Street
# 8640  manhattan                 Lincoln Square  60 Riverside Boulevard
# 8641  manhattan                    Murray Hill    311 East 38th Street
# 8642  manhattan                 Lincoln Square  60 Riverside Boulevard
#
#       Num_Beds  Num_Baths    Sq-Ft    Rent       Long        Lat ZipCode  \
# 0          2.0        2.0  1377.37  9150.0 -73.997478  40.738415   10011
# 1          2.0        2.0  1085.00  6276.0 -73.972708  40.743649   10016
# 2          2.0        1.0   855.99  2646.0 -73.938373  40.836002   10032
# 3          0.5        1.0   537.89  1950.0 -73.950435  40.806607   10027
# 4          1.0        2.0   851.00  5869.0 -73.963335  40.755807   10022
# ...        ...        ...      ...     ...        ...        ...     ...
# 8638       2.0        1.0   847.94  2400.0 -73.944524  40.818872   10030
# 8639       1.0        1.0   651.00  7805.0 -73.985138  40.743679   10016
# 8640       1.0        1.0   727.00  5380.0 -73.990935  40.774579   10069
# 8641       1.0        1.0   725.00  3700.0 -73.973377  40.747112   10016
# 8642       1.0        1.0   866.00  6005.0 -73.990935  40.774579   10069
#
#       Precinct  CrimeTotalPastYear Train_Line
# 0         13.0              1549.0          L
# 1         13.0              1549.0          7
# 2         33.0              1126.0        A-C
# 3         28.0              1017.0        B-D
# 4         18.0              1926.0          E
# ...        ...                 ...        ...
# 8638      32.0              1278.0        B-D
# 8639      13.0              1549.0      4-5-6
# 8640      20.0              1120.0      1-2-3
# 8641      14.0              2869.0          7
# 8642      20.0              1120.0      1-2-3
#
# [8643 rows x 13 columns]

# %%
df.to_csv(csv, index=False)

# %%
df.columns
# Out:
# Index(['Borough', 'Area', 'Address', 'Num_Beds', 'Num_Baths', 'Sq-Ft', 'Rent',
#        'Long', 'Lat', 'ZipCode', 'Precinct', 'CrimeTotalPastYear',
#        'Train_Line'],
#       dtype='object')

# %%
# Bed, Bath, Sq-Ft, Rent, Correlation

df1 = df[['Num_Beds', 'Num_Baths', 'Sq-Ft', 'Rent']]

# %%
corr_mat1 = df1.corr(method='pearson')
mask = np.triu(np.ones_like(corr_mat1, dtype=bool))

f, ax = plt.subplots(figsize=(11, 11))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_mat1, mask=mask, cmap=cmap, robust=True, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
lim_plot = sns.scatterplot(data=df, x='Long', y='Lat', hue='Rent', size='Sq-Ft', sizes=(50, 650), x_jitter=True, y_jitter=True)
lim_plot.set_xlim(-74.1, -73.8)
lim_plot.set_ylim(30, 45)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Train_Line', size='Rent', sizes=(50, 700), palette=sns.color_palette('deep', df['Train_Line'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='CrimeTotalPastYear', size='Rent', sizes=(50, 650))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Area', size='Rent', sizes=(50, 700), palette=sns.color_palette('deep', df['Area'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# correlation between crime and rent

df3 = df[['Sq-Ft', 'Num_Beds', 'Num_Baths', 'CrimeTotalPastYear', 'Rent']]

# %%
corr_mat3 = df3.corr(method='pearson')
mask = np.triu(np.ones_like(corr_mat3, dtype=bool))

f, ax = plt.subplots(figsize=(11, 11))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_mat3, mask=mask, cmap=cmap, robust=True, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df, x='Long', y='Lat', hue='Precinct', size='CrimeTotalPastYear', sizes=(50, 700), palette=sns.color_palette('deep', df['Precinct'].unique().shape[0]))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
